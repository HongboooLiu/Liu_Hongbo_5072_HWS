# %% [markdown]
# # HW1
# # Hongbo Liu

# %% [markdown]
# 1. Create a Jupyter Notebook

# %% [markdown]
# https://whatsthebigdata.com/

# %% [markdown]
# ![d3a05d2c7ceb291badccbe0868059ad.png](attachment:d3a05d2c7ceb291badccbe0868059ad.png)

# %% [markdown]
# 2. Markdown quote

# %% [markdown]
# > Truth is the offspring of silence and unbroken meditation.
#
# > _Isaac Newton_

# %% [markdown]
# 3. Latex formula and plot

# %%
from matplotlib import pyplot as plt 
import numpy as np

# %%
x=np.array(range(0,1000))
y=x**3

plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# $$y=x^3$$

# %% [markdown]
# 4. Markdown table

# %% [markdown]
# | packages| github stars |
# | --- | --- |
# | pandas | 35.2K |
# | matplotlib | 16.1K |
# | numpy | 21.5K |
# | seaborn | 9.8K |
# | tensorflow | 168K |

# %% [markdown]
# 5. Execute shell command

# %%
# !cd
# Out:
# C:\Users\22151

# %% [markdown]
# 6. Run some external script

# %%
# %%writefile file1.py
print("The answer is 42.")
# Out:
# Writing file1.py

# %%
# %load file1.py
print("The answer is 42.")

# %%
# %run file1.py
# Out:
# The answer is 42.
